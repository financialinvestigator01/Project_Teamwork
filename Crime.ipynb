# %%
#%matplotlib notebook
# %matplotlib inline

#dependencies and setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

#files to load 

Crime_data_to_load = "data/Hate_crime.csv"
Police_data_to_load = "data/Police_Employee_data.csv"
Unemployment_data_to_load = "data/Unemployment.csv"
Poverty_data_to_load = "data/poverty_2017.csv"

#read the csv files

crime_df = pd.read_csv(Crime_data_to_load)
police_df = pd.read_csv(Police_data_to_load)
unemployment_df = pd.read_csv(Unemployment_data_to_load)
poverty_df = pd.read_csv(Poverty_data_to_load)
# Out:
# /Users/parinmody/Desktop/anaconda3/envs/PythonData/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # clean up crime_df dataframe

# %%
#rename columns in crime_df dataframe
crime_df = crime_df.rename(columns={'INCIDENT_ID': 'ID', 'DATA_YEAR': 'Year', 'PUB_AGENCY_UNIT':'Agency Unit','PUB_AGENCY_NAME': 'Agency Name', 
                         'AGENCY_TYPE_NAME': 'Agency Type', 'STATE_ABBR': 'State Abbr.', 'STATE_NAME': 'State', 'DIVISION_NAME':'Division',
                         'REGION_NAME': 'Region', 'POPULATION_GROUP_CODE':'Pop. Group Code', 'POPULATION_GROUP_DESC':'Pop. Group Desc.',
                         'INCIDENT_DATE':'Incident Date','ADULT_VICTIM_COUNT': 'Adult Victim Count', 'JUVENILE_VICTIM_COUNT': 'Juvenile Victim Count',
                         'TOTAL_OFFENDER_COUNT': 'Total Offender Count', 'ADULT_OFFENDER_COUNT': 'Adult Offender Count', 
                         'JUVENILLE_OFFENDER_COUNT':'Juvenille Offender Count','OFFENDER_RACE':'Offender Race', 'OFFENDER_ETHNICITY': 'Offender Ethnicity', 
                         'VICTIM_COUNT': 'Victim Count', 'OFFENSE_NAME':'Offense Name', 'TOTAL_INDIVIDUAL_VICTIMS': 'Total Indiv. Victims',
                         'LOCATION_NAME': 'Location', 'BIAS_DESC':'Bias Desc', 'VICTIM_TYPES': 'Victim Type', 'MULTIPLE_OFFENSE': 
                         'Multiple Offense', 'MULTIPLE_BIAS': 'Multiple Bias'
                        }) 

#drop all null values in dataframe
#crime_df.dropna()

crime_df
# Out:
#             ID  Year        ORI                  Agency Name Agency Unit  \
# 0         3015  1991  AR0040200                       Rogers         NaN
# 1         3016  1991  AR0290100                         Hope         NaN
# 2           43  1991  AR0350100                   Pine Bluff         NaN
# 3           44  1991  AR0350100                   Pine Bluff         NaN
# 4         3017  1991  AR0350100                   Pine Bluff         NaN
# 5         3018  1991  AR0350100                   Pine Bluff         NaN
# 6         3019  1991  AR0600200                  Little Rock         NaN
# 7           45  1991  AR0600300            North Little Rock         NaN
# 8           46  1991  AR0600300            North Little Rock         NaN
# 9         3020  1991  AR0600300            North Little Rock         NaN
# 10        3021  1991  AR0600300            North Little Rock         NaN
# 11          47  1991  AR0670000                       Sevier         NaN
# 12           2  1991  AZ0072300                      Phoenix         NaN
# 13           3  1991  AZ0072300                      Phoenix         NaN
# 14           4  1991  AZ0072300                      Phoenix         NaN
# 15           5  1991  AZ0072300                      Phoenix         NaN
# 16           6  1991  AZ0072300                      Phoenix         NaN
# 17           7  1991  AZ0072300                      Phoenix         NaN
# 18           8  1991  AZ0072300                      Phoenix         NaN
# 19           9  1991  AZ0072300                      Phoenix         NaN
# 20          10  1991  AZ0072300                      Phoenix         NaN
# 21          11  1991  AZ0072300                      Phoenix         NaN
# 22          12  1991  AZ0072300                      Phoenix         NaN
# 23          13  1991  AZ0072300                      Phoenix         NaN
# 24          14  1991  AZ0072300                      Phoenix         NaN
# 25          15  1991  AZ0072300                      Phoenix         NaN
# 26          16  1991  AZ0072300                      Phoenix         NaN
# 27          17  1991  AZ0072300                      Phoenix         NaN
# 28          18  1991  AZ0072300                      Phoenix         NaN
# 29          19  1991  AZ0072300                      Phoenix         NaN
# ...        ...   ...        ...                          ...         ...
# 194164  308075  2017  WV0100500                     Oak Hill         NaN
# 194165  308078  2017  WV0100500                     Oak Hill         NaN
# 194166  308079  2017  WV0100500                     Oak Hill         NaN
# 194167  290144  2017  WV0130400        White Sulphur Springs         NaN
# 194168  308077  2017  WV0170000                     Harrison         NaN
# 194169  290110  2017  WV0170100                   Bridgeport         NaN
# 194170  290125  2017  WV0190000                    Jefferson         NaN
# 194171  308115  2017  WV0190300                       Ranson         NaN
# 194172  290112  2017  WV0190700          Shepherd University         NaN
# 194173  290128  2017  WV0190700          Shepherd University         NaN
# 194174  290129  2017  WV0190700          Shepherd University         NaN
# 194175  290109  2017  WV0200200                   Charleston         NaN
# 194176  290127  2017  WV0200200                   Charleston         NaN
# 194177  290141  2017  WV0200200                   Charleston         NaN
# 194178  290142  2017  WV0200200                   Charleston         NaN
# 194179  290151  2017  WV0200800                       Marmet         NaN
# 194180  290152  2017  WV0200800                       Marmet         NaN
# 194181  308096  2017  WV0203400  Capitol Protective Services         NaN
# 194182  290145  2017  WV0210000                        Lewis         NaN
# 194183  290146  2017  WV0210000                        Lewis         NaN
# 194184  290118  2017  WV0240000                     McDowell         NaN
# 194185  290130  2017  WV0240000                     McDowell         NaN
# 194186  308073  2017  WV0250100                     Fairmont         NaN
# 194187  290187  2017  WV0270000                        Mason         NaN
# 194188  290186  2017  WV0490100                   Buckhannon         NaN
# 194189  308074  2017  WV0540100                  Parkersburg         NaN
# 194190  190213  2017  WY0010100                      Laramie         NaN
# 194191  193399  2017  WY0010100                      Laramie         NaN
# 194192  194469  2017  WY0010200        University of Wyoming         NaN
# 194193  192225  2017  WY0170100                     Sheridan         NaN
#
#                   Agency Type State Abbr.          State            Division  \
# 0                        City          AR       Arkansas  West South Central
# 1                        City          AR       Arkansas  West South Central
# 2                        City          AR       Arkansas  West South Central
# 3                        City          AR       Arkansas  West South Central
# 4                        City          AR       Arkansas  West South Central
# 5                        City          AR       Arkansas  West South Central
# 6                        City          AR       Arkansas  West South Central
# 7                        City          AR       Arkansas  West South Central
# 8                        City          AR       Arkansas  West South Central
# 9                        City          AR       Arkansas  West South Central
# 10                       City          AR       Arkansas  West South Central
# 11                     County          AR       Arkansas  West South Central
# 12                       City          AZ        Arizona            Mountain
# 13                       City          AZ        Arizona            Mountain
# 14                       City          AZ        Arizona            Mountain
# 15                       City          AZ        Arizona            Mountain
# 16                       City          AZ        Arizona            Mountain
# 17                       City          AZ        Arizona            Mountain
# 18                       City          AZ        Arizona            Mountain
# 19                       City          AZ        Arizona            Mountain
# 20                       City          AZ        Arizona            Mountain
# 21                       City          AZ        Arizona            Mountain
# 22                       City          AZ        Arizona            Mountain
# 23                       City          AZ        Arizona            Mountain
# 24                       City          AZ        Arizona            Mountain
# 25                       City          AZ        Arizona            Mountain
# 26                       City          AZ        Arizona            Mountain
# 27                       City          AZ        Arizona            Mountain
# 28                       City          AZ        Arizona            Mountain
# 29                       City          AZ        Arizona            Mountain
# ...                       ...         ...            ...                 ...
# 194164                   City          WV  West Virginia      South Atlantic
# 194165                   City          WV  West Virginia      South Atlantic
# 194166                   City          WV  West Virginia      South Atlantic
# 194167                   City          WV  West Virginia      South Atlantic
# 194168                 County          WV  West Virginia      South Atlantic
# 194169                   City          WV  West Virginia      South Atlantic
# 194170                 County          WV  West Virginia      South Atlantic
# 194171                   City          WV  West Virginia      South Atlantic
# 194172  University or College          WV  West Virginia      South Atlantic
# 194173  University or College          WV  West Virginia      South Atlantic
# 194174  University or College          WV  West Virginia      South Atlantic
# 194175                   City          WV  West Virginia      South Atlantic
# 194176                   City          WV  West Virginia      South Atlantic
# 194177                   City          WV  West Virginia      South Atlantic
# 194178                   City          WV  West Virginia      South Atlantic
# 194179                   City          WV  West Virginia      South Atlantic
# 194180                   City          WV  West Virginia      South Atlantic
# 194181     Other State Agency          WV  West Virginia      South Atlantic
# 194182                 County          WV  West Virginia      South Atlantic
# 194183                 County          WV  West Virginia      South Atlantic
# 194184                 County          WV  West Virginia      South Atlantic
# 194185                 County          WV  West Virginia      South Atlantic
# 194186                   City          WV  West Virginia      South Atlantic
# 194187                 County          WV  West Virginia      South Atlantic
# 194188                   City          WV  West Virginia      South Atlantic
# 194189                   City          WV  West Virginia      South Atlantic
# 194190                   City          WY        Wyoming            Mountain
# 194191                   City          WY        Wyoming            Mountain
# 194192  University or College          WY        Wyoming            Mountain
# 194193                   City          WY        Wyoming            Mountain
#
#        Region      ...                   Offender Race Offender Ethnicity  \
# 0       South      ...                           White                NaN
# 1       South      ...       Black or African American                NaN
# 2       South      ...       Black or African American                NaN
# 3       South      ...       Black or African American                NaN
# 4       South      ...       Black or African American                NaN
# 5       South      ...       Black or African American                NaN
# 6       South      ...       Black or African American                NaN
# 7       South      ...       Black or African American                NaN
# 8       South      ...       Black or African American                NaN
# 9       South      ...       Black or African American                NaN
# 10      South      ...       Black or African American                NaN
# 11      South      ...                           White                NaN
# 12       West      ...                         Unknown                NaN
# 13       West      ...                         Unknown                NaN
# 14       West      ...                         Unknown                NaN
# 15       West      ...                           White                NaN
# 16       West      ...                         Unknown                NaN
# 17       West      ...                         Unknown                NaN
# 18       West      ...                           White                NaN
# 19       West      ...                           White                NaN
# 20       West      ...                         Unknown                NaN
# 21       West      ...                           White                NaN
# 22       West      ...                         Unknown                NaN
# 23       West      ...                           White                NaN
# 24       West      ...                         Unknown                NaN
# 25       West      ...                         Unknown                NaN
# 26       West      ...                           White                NaN
# 27       West      ...                           White                NaN
# 28       West      ...                           White                NaN
# 29       West      ...                         Unknown                NaN
# ...       ...      ...                             ...                ...
# 194164  South      ...       Black or African American            Unknown
# 194165  South      ...                           White            Unknown
# 194166  South      ...                           White            Unknown
# 194167  South      ...       Black or African American            Unknown
# 194168  South      ...                         Unknown            Unknown
# 194169  South      ...                           White            Unknown
# 194170  South      ...       Black or African American            Unknown
# 194171  South      ...                         Unknown            Unknown
# 194172  South      ...                         Unknown            Unknown
# 194173  South      ...                         Unknown            Unknown
# 194174  South      ...                         Unknown            Unknown
# 194175  South      ...       Black or African American            Unknown
# 194176  South      ...                           White            Unknown
# 194177  South      ...                           White            Unknown
# 194178  South      ...                           White            Unknown
# 194179  South      ...                           White            Unknown
# 194180  South      ...                         Unknown            Unknown
# 194181  South      ...                         Unknown            Unknown
# 194182  South      ...                           White            Unknown
# 194183  South      ...                           White            Unknown
# 194184  South      ...                           White            Unknown
# 194185  South      ...                           White            Unknown
# 194186  South      ...                           White            Unknown
# 194187  South      ...                         Unknown            Unknown
# 194188  South      ...                           White            Unknown
# 194189  South      ...                           White            Unknown
# 194190   West      ...                         Unknown            Unknown
# 194191   West      ...                         Unknown            Unknown
# 194192   West      ...                        Multiple           Multiple
# 194193   West      ...                           White            Unknown
#
#        Victim Count                                       Offense Name  \
# 0                 1                                       Intimidation
# 1                 1                                     Simple Assault
# 2                 1                                 Aggravated Assault
# 3                 2  Aggravated Assault;Destruction/Damage/Vandalis...
# 4                 1                                 Aggravated Assault
# 5                 1                                            Robbery
# 6                 1                                 Aggravated Assault
# 7                 2  Aggravated Assault;Murder and Nonnegligent Man...
# 8                 1                                       Intimidation
# 9                 1                                            Robbery
# 10                1                                       Intimidation
# 11                1                                       Intimidation
# 12                1                                       Intimidation
# 13                1                                       Intimidation
# 14                1                                       Intimidation
# 15                1                                 Aggravated Assault
# 16                1           Destruction/Damage/Vandalism of Property
# 17                1                                       Intimidation
# 18                1                                     Simple Assault
# 19                1                                       Intimidation
# 20                1           Destruction/Damage/Vandalism of Property
# 21                1                                       Intimidation
# 22                1                                       Intimidation
# 23                1                                       Intimidation
# 24                1           Destruction/Damage/Vandalism of Property
# 25                1           Destruction/Damage/Vandalism of Property
# 26                1                                       Intimidation
# 27                1                                 Aggravated Assault
# 28                1                                 Aggravated Assault
# 29                1                                       Intimidation
# ...             ...                                                ...
# 194164            1           Destruction/Damage/Vandalism of Property
# 194165            1                                     Simple Assault
# 194166            1                           Drug/Narcotic Violations
# 194167            1                                     Simple Assault
# 194168            1           Destruction/Damage/Vandalism of Property
# 194169            1                                  All Other Larceny
# 194170            1                                  All Other Larceny
# 194171            1                                 Aggravated Assault
# 194172            1           Destruction/Damage/Vandalism of Property
# 194173            1           Destruction/Damage/Vandalism of Property
# 194174            1           Destruction/Damage/Vandalism of Property
# 194175            1                                            Robbery
# 194176            1                                     Simple Assault
# 194177            1                                     Simple Assault
# 194178            1                                     Simple Assault
# 194179            1                                     Simple Assault
# 194180            1                       Burglary/Breaking & Entering
# 194181            1           Destruction/Damage/Vandalism of Property
# 194182            1                           Drug/Narcotic Violations
# 194183            1           Destruction/Damage/Vandalism of Property
# 194184            1                           Stolen Property Offenses
# 194185            1                                Motor Vehicle Theft
# 194186            4  Destruction/Damage/Vandalism of Property;Motor...
# 194187            1                                Motor Vehicle Theft
# 194188            1                                        Shoplifting
# 194189            2  Destruction/Damage/Vandalism of Property;Weapo...
# 194190            1           Destruction/Damage/Vandalism of Property
# 194191            1           Destruction/Damage/Vandalism of Property
# 194192            1                                       Intimidation
# 194193            1                                     Simple Assault
#
#         Total Indiv. Victims                            Location  \
# 0                        1.0  Highway/Road/Alley/Street/Sidewalk
# 1                        1.0  Highway/Road/Alley/Street/Sidewalk
# 2                        1.0                      Residence/Home
# 3                        1.0  Highway/Road/Alley/Street/Sidewalk
# 4                        1.0                 Service/Gas Station
# 5                        1.0                 Grocery/Supermarket
# 6                        1.0                      School/College
# 7                        2.0                      Residence/Home
# 8                        1.0                      Residence/Home
# 9                        2.0  Highway/Road/Alley/Street/Sidewalk
# 10                       1.0                      Residence/Home
# 11                       1.0                      School/College
# 12                       1.0                      Residence/Home
# 13                       1.0      Church/Synagogue/Temple/Mosque
# 14                       1.0                      Residence/Home
# 15                       1.0  Highway/Road/Alley/Street/Sidewalk
# 16                       0.0      Church/Synagogue/Temple/Mosque
# 17                       1.0                      Residence/Home
# 18                       1.0                       Other/Unknown
# 19                       1.0                       Other/Unknown
# 20                       1.0                      Residence/Home
# 21                       1.0                      Residence/Home
# 22                       1.0          Commercial/Office Building
# 23                       1.0                      Residence/Home
# 24                       0.0      Church/Synagogue/Temple/Mosque
# 25                       0.0      Church/Synagogue/Temple/Mosque
# 26                       1.0              Air/Bus/Train Terminal
# 27                       3.0             Parking/Drop Lot/Garage
# 28                       1.0                       Other/Unknown
# 29                       1.0      Church/Synagogue/Temple/Mosque
# ...                      ...                                 ...
# 194164                   1.0                      Residence/Home
# 194165                   1.0                      Residence/Home
# 194166                   0.0                 Grocery/Supermarket
# 194167                   1.0                      Residence/Home
# 194168                   1.0  Highway/Road/Alley/Street/Sidewalk
# 194169                   1.0                      Residence/Home
# 194170                   0.0           Department/Discount Store
# 194171                   1.0             Parking/Drop Lot/Garage
# 194172                   0.0                      School/College
# 194173                   0.0                      School/College
# 194174                   0.0                      School/College
# 194175                   1.0  Highway/Road/Alley/Street/Sidewalk
# 194176                   1.0                      Residence/Home
# 194177                   1.0               Bank/Savings and Loan
# 194178                   1.0             Parking/Drop Lot/Garage
# 194179                   1.0                      Residence/Home
# 194180                   1.0                      Residence/Home
# 194181                   0.0          Government/Public Building
# 194182                   0.0             Parking/Drop Lot/Garage
# 194183                   0.0          Government/Public Building
# 194184                   1.0                      Residence/Home
# 194185                   1.0  Highway/Road/Alley/Street/Sidewalk
# 194186                   1.0  Highway/Road/Alley/Street/Sidewalk
# 194187                   1.0             Parking/Drop Lot/Garage
# 194188                   0.0                   Convenience Store
# 194189                   1.0             Parking/Drop Lot/Garage
# 194190                   NaN      Church/Synagogue/Temple/Mosque
# 194191                   NaN                          Restaurant
# 194192                  20.0  Highway/Road/Alley/Street/Sidewalk
# 194193                   1.0                       Bar/Nightclub
#
#                                                 Bias Desc  \
# 0                          Anti-Black or African American
# 1                                              Anti-White
# 2                          Anti-Black or African American
# 3                                              Anti-White
# 4                                              Anti-White
# 5                                              Anti-White
# 6                                              Anti-White
# 7                                              Anti-White
# 8                                              Anti-White
# 9                                              Anti-White
# 10                                             Anti-White
# 11                         Anti-Black or African American
# 12                         Anti-Black or African American
# 13                                            Anti-Jewish
# 14                                              Anti-Arab
# 15                         Anti-Black or African American
# 16                                        Anti-Protestant
# 17                         Anti-Black or African American
# 18                         Anti-Black or African American
# 19                                            Anti-Jewish
# 20                         Anti-Black or African American
# 21                                              Anti-Arab
# 22                         Anti-Black or African American
# 23                         Anti-Black or African American
# 24                                        Anti-Protestant
# 25                                        Anti-Protestant
# 26                                            Anti-Jewish
# 27                         Anti-Black or African American
# 28                         Anti-Black or African American
# 29                                    Anti-Other Religion
# ...                                                   ...
# 194164                            Anti-Hispanic or Latino
# 194165                                         Anti-White
# 194166                                         Anti-White
# 194167                     Anti-Multiple Religions, Group
# 194168                                        Anti-Jewish
# 194169              Anti-American Indian or Alaska Native
# 194170              Anti-American Indian or Alaska Native
# 194171                            Anti-Hispanic or Latino
# 194172                                        Anti-Jewish
# 194173                         Anti-Multiple Races, Group
# 194174                         Anti-Multiple Races, Group
# 194175                                         Anti-White
# 194176                                         Anti-White
# 194177                              Anti-Lesbian (Female)
# 194178                     Anti-Black or African American
# 194179                 Anti-Other Race/Ethnicity/Ancestry
# 194180  Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 194181                     Anti-Black or African American
# 194182                 Anti-Other Race/Ethnicity/Ancestry
# 194183                           Anti-Physical Disability
# 194184                                         Anti-White
# 194185                                         Anti-White
# 194186                                         Anti-White
# 194187                                         Anti-White
# 194188                                         Anti-White
# 194189                     Anti-Black or African American
# 194190                                    Anti-Protestant
# 194191  Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 194192              Anti-American Indian or Alaska Native
# 194193                                    Anti-Gay (Male)
#
#                       Victim Type Multiple Offense Multiple Bias
# 0                      Individual                S             S
# 1                      Individual                S             S
# 2                      Individual                S             S
# 3                      Individual                M             S
# 4                      Individual                S             S
# 5                      Individual                S             S
# 6                      Individual                S             S
# 7                      Individual                M             S
# 8                      Individual                S             S
# 9                      Individual                S             S
# 10                     Individual                S             S
# 11                     Individual                S             S
# 12                     Individual                S             S
# 13                     Individual                S             S
# 14                     Individual                S             S
# 15                     Individual                S             S
# 16         Religious Organization                S             S
# 17                     Individual                S             S
# 18                     Individual                S             S
# 19                     Individual                S             S
# 20                     Individual                S             S
# 21                     Individual                S             S
# 22                     Individual                S             S
# 23                     Individual                S             S
# 24         Religious Organization                S             S
# 25         Religious Organization                S             S
# 26                     Individual                S             S
# 27                     Individual                S             S
# 28                     Individual                S             S
# 29                     Individual                S             S
# ...                           ...              ...           ...
# 194164                 Individual                S             S
# 194165                 Individual                S             S
# 194166             Society/Public                S             S
# 194167                 Individual                S             S
# 194168                 Individual                S             S
# 194169                 Individual                S             S
# 194170                   Business                S             S
# 194171                 Individual                S             S
# 194172                 Government                S             S
# 194173                 Government                S             S
# 194174                   Business                S             S
# 194175                 Individual                S             S
# 194176                 Individual                S             S
# 194177                 Individual                S             S
# 194178                 Individual                S             S
# 194179                 Individual                S             S
# 194180                 Individual                S             S
# 194181                 Government                S             S
# 194182             Society/Public                S             S
# 194183                 Government                S             S
# 194184                 Individual                S             S
# 194185                 Individual                S             S
# 194186      Government;Individual                M             S
# 194187                 Individual                S             S
# 194188                   Business                S             S
# 194189  Individual;Society/Public                M             S
# 194190     Religious Organization                S             S
# 194191                   Business                S             S
# 194192                 Individual                S             S
# 194193                 Individual                S             S
#
# [194194 rows x 28 columns]

# %% [markdown]
# # clean up police_df dataframe

# %%
#rename columns in police_df dataframe
police_df = police_df.rename(columns={'state_abbr': 'State Abbr.', 'data_year': 'Year','population': 'Population',
                                      'male_officer_ct':'Male Officer Count', 'male_civilian_ct': 'Male Civilian Count',
                                      'male_total_ct':'Male Total Count', 'female_officer_ct':'Female Officer Count',
                                      'female_civilian_ct':'Female Civilian Count', 'female_total_ct':'Female Total Count',
                                      'officer_ct':'Officer Count', 'civilian_ct': 'Civilian Count', "total_pe_ct":
                                      'Total Police Employee Count', 'pe_ct_per_1000':'Police Employee Count/1000'
                                      })

police_df.head()
# Out:
#   State Abbr.  Year  Population  Male Officer Count  Male Civilian Count  \
# 0          AK  2000      631027              1066.0                208.0
# 1          AL  2000     4488050              9529.0               1847.0
# 2          AR  2000     2934348              5315.0               1130.0
# 3          AS  2000           0                 NaN                  NaN
# 4          AZ  2000     5248863              9461.0               3364.0
#
#    Male Total Count  Female Officer Count  Female Civilian Count  \
# 0            1274.0                 103.0                  481.0
# 1           11376.0                 769.0                 3176.0
# 2            6445.0                 541.0                 1814.0
# 3               NaN                   NaN                    NaN
# 4           12825.0                1117.0                 4319.0
#
#    Female Total Count  Officer Count  Civilian Count  \
# 0               584.0         1169.0           689.0
# 1              3945.0        10298.0          5023.0
# 2              2355.0         5856.0          2944.0
# 3                 NaN            NaN             NaN
# 4              5436.0        10578.0          7683.0
#
#    Total Police Employee Count  Police Employee Count/1000
# 0                       1858.0                        2.94
# 1                      15321.0                        3.41
# 2                       8800.0                        3.00
# 3                          NaN                         NaN
# 4                      18261.0                        3.48

# %% [markdown]
# #  clean up unemployment_df dataframe

# %%
#original unemployment dataframe
unemployment_df

#selecting only the columns needed from original dataframe as part of cleaning it up
cleaned_unemployment_df = unemployment_df[["Unnamed: 4", "Unnamed: 6", "Unnamed: 8", "Unnamed: 10", "Unnamed: 12",
                                          "Unnamed: 14", "Unnamed: 16", "Unnamed: 18", "Unnamed: 20", 
                                          "Unnamed: 22", "Unnamed: 23"]]

#renaming column names
cleaned_unemployment_df.columns = ['State', '2009','2010','2011','2012','2013','2014','2015',
                                   '2016','2017','Median Household Income']

#dropping the first row as part of cleaning the dataframe up 
cleaned_unemployment_df = cleaned_unemployment_df.drop(cleaned_unemployment_df.index[0])

#filling in null values with a 0
cleaned_unemployment_df = cleaned_unemployment_df.fillna(0)

cleaned_unemployment_df.head()
# Out:
#         State  2009  2010  2011  2012  2013  2014  2015 2016  2017  \
# 1     Alabama  11.0  10.5   9.6   8.0   7.2   6.8   6.1  5.9   4.4
# 2      Alaska   7.7   7.9   7.6   7.1   7.0   6.9   6.5  6.9   7.2
# 3     Arizona   9.9  10.4   9.5   8.3   7.7   6.8   6.1  5.4   4.9
# 4    Arkansas   7.8   8.2   8.3   7.6   7.2   6.0   5.0  3.9   3.7
# 5  California  11.2  12.2  11.7  10.4   8.9   7.5   6.2  5.5   4.8
#
#   Median Household Income
# 1                $48,193
# 2                $74,058
# 3                $56,508
# 4                $45,916
# 5                $71,785

# %% [markdown]
# # clean up poverty_df dataframe

# %%
#original poverty dataframe
poverty_df

#selecting only the columns needed from original dataframe as part of cleaning it up
cleaned_poverty_df = poverty_df[["Name", "Percent", "Lower Bound",
                                "Upper Bound", "Percent.1", "Lower Bound.1", "Upper Bound.1"]]


#renaming column names
cleaned_poverty_df.columns = ['State', 'Percent (All People in Poverty)', 'Lower Bound', 'Upper Bound', 
                              'Percent (Children 0-17 in Poverty)', 'Lower Bound', 'Upper Bound']


#dropping the first row as part of cleaning the dataframe up 
cleaned_poverty_df = cleaned_poverty_df.drop(cleaned_poverty_df.index[0:3])

#filling in null values with a 0
cleaned_poverty_df = cleaned_poverty_df.fillna(0)

cleaned_poverty_df.head()
# Out:
#          State  Percent (All People in Poverty)  Lower Bound  Upper Bound  \
# 3     Arkansas                             16.3         15.9         16.7
# 4   California                             13.3         13.2         13.4
# 5     Colorado                             10.3         10.0         10.6
# 6  Connecticut                              9.7          9.3         10.1
# 7     Delaware                             13.0         12.4         13.6
#
#    Percent (Children 0-17 in Poverty)  Lower Bound  Upper Bound
# 3                                22.5         21.5         23.5
# 4                                18.1         17.8         18.4
# 5                                12.2         11.5         12.9
# 6                                13.0         12.2         13.8
# 7                                17.7         16.5         18.9

# %% [markdown]
# # merge crime_df and police_df

# %%
#merge the crime dataframe and the police dataframe
crime_police_merged = pd.merge(crime_df, police_df, on=("State Abbr.","Year"))
crime_police_merged.head()
# Out:
#       ID  Year        ORI   Agency Name Agency Unit Agency Type State Abbr.  \
# 0  70308  2000  AK0010100     Anchorage         NaN        City          AK
# 1  70309  2000  AK0010100     Anchorage         NaN        City          AK
# 2  70310  2000  AK0010100     Anchorage         NaN        City          AK
# 3  70311  2000  AK0010100     Anchorage         NaN        City          AK
# 4  65648  2000  AR0080300  Green Forest         NaN        City          AR
#
#       State            Division Region            ...              \
# 0    Alaska             Pacific   West            ...
# 1    Alaska             Pacific   West            ...
# 2    Alaska             Pacific   West            ...
# 3    Alaska             Pacific   West            ...
# 4  Arkansas  West South Central  South            ...
#
#   Male Officer Count Male Civilian Count Male Total Count  \
# 0             1066.0               208.0           1274.0
# 1             1066.0               208.0           1274.0
# 2             1066.0               208.0           1274.0
# 3             1066.0               208.0           1274.0
# 4             5315.0              1130.0           6445.0
#
#    Female Officer Count  Female Civilian Count  Female Total Count  \
# 0                 103.0                  481.0               584.0
# 1                 103.0                  481.0               584.0
# 2                 103.0                  481.0               584.0
# 3                 103.0                  481.0               584.0
# 4                 541.0                 1814.0              2355.0
#
#    Officer Count  Civilian Count Total Police Employee Count  \
# 0         1169.0           689.0                      1858.0
# 1         1169.0           689.0                      1858.0
# 2         1169.0           689.0                      1858.0
# 3         1169.0           689.0                      1858.0
# 4         5856.0          2944.0                      8800.0
#
#   Police Employee Count/1000
# 0                       2.94
# 1                       2.94
# 2                       2.94
# 3                       2.94
# 4                       3.00
#
# [5 rows x 39 columns]

# %% [markdown]
# # filter crime & police merged dataframe to data we need

# %%
#shorten the merged crime & police dataframe 
crime_police_shorter = crime_police_merged.loc[:, ["State Abbr.", "Year", "Male Officer Count",
                                                   "Female Officer Count","Total Offender Count"]]

#select years between 2014 - 2017
year = (crime_police_shorter["Year"] >= 2014) &  (crime_police_shorter['Year'] <= 2017)
crime_police_shorter = crime_police_shorter.loc[year]

#groupby state and year for analysis of crime and police force per state per year
grouped_data = crime_police_shorter.groupby(['State Abbr.', 'Year'])

#sum up the total male officer count, female officer count and total offender count for each year per state
grouped_data.sum().head()
# Out:
#                   Male Officer Count  Female Officer Count  \
# State Abbr. Year
# AK          2014              7254.0                 696.0
#             2015              9600.0                 928.0
#             2016             12716.0                1243.0
#             2017              4540.0                 448.0
# AL          2014            108468.0                8640.0
#
#                   Total Offender Count
# State Abbr. Year
# AK          2014                     8
#             2015                     9
#             2016                     6
#             2017                     2
# AL          2014                    11

# %% [markdown]
# # create bar graph for 2014

# %%
#create 2014 bar graph

year_2014 = (crime_police_shorter["Year"] == 2014)

crime_police_shorter = crime_police_shorter.loc[year_2014]
crime_police_shorter

grouped_data_2014 = crime_police_shorter.groupby(['State Abbr.', 'Year'])
grouped_data_2014.sum().head()
# Out:
#                   Male Officer Count  Female Officer Count  \
# State Abbr. Year
# AK          2014              7254.0                 696.0
# AL          2014            108468.0                8640.0
# AR          2014             62760.0                5490.0
# AZ          2014           3031865.0              354570.0
# CA          2014          51801750.0             7736487.0
#
#                   Total Offender Count
# State Abbr. Year
# AK          2014                     8
# AL          2014                    11
# AR          2014                    15
# AZ          2014                   223
# CA          2014                   800

# %%
x_axis = (np.arange(1,51,1))
tick_locations = [value+0.4 for value in x_axis]


plt.figure(figsize=(10,3))
plt.bar(x_axis, grouped_data["Male Officer Count"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, grouped_data["State Abbr."], rotation="vertical")

# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(grouped_data["Male Officer Count"])+10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-28eb6c7db3f3> in <module>
#       4
#       5 plt.figure(figsize=(10,3))
# ----> 6 plt.bar(x_axis, grouped_data["Male Officer Count"], color='r', alpha=0.5, align="edge")
#       7 plt.xticks(tick_locations, grouped_data["State Abbr."], rotation="vertical")
#       8
#
# ~/Desktop/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2457     return gca().bar(
#    2458         x, height, width=width, bottom=bottom, align=align,
# -> 2459         **({"data": data} if data is not None else {}), **kwargs)
#    2460
#    2461
#
# ~/Desktop/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/Desktop/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2249         x, height, width, y, linewidth = np.broadcast_arrays(
#    2250             # Make args iterable too.
# -> 2251             np.atleast_1d(x), height, width, y, linewidth)
#    2252
#    2253         # Now that units have been converted, set the tick locations.
#
# ~/Desktop/anaconda3/envs/PythonData/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     250     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     251
# --> 252     shape = _broadcast_shape(*args)
#     253
#     254     if all(array.shape == shape for array in args):
#
# ~/Desktop/anaconda3/envs/PythonData/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     185     # use the old-iterator because np.nditer does not handle size 0 arrays
#     186     # consistently
# --> 187     b = np.broadcast(*args[:32])
#     188     # unfortunately, it cannot handle 32 or more arguments directly
#     189     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %% [markdown]
# # unemployment rate by state in 2017

# %%
cleaned_unemployment_df

unemployment_2017 = cleaned_unemployment_df.iloc[:, [0,-2]]

unemployment_2017

x_axis = (unemployment_2017["State"])
y_axis = (unemployment_2017["2017"]

plt.bar(x_axis, y_axis)
# Out:
#   File "<ipython-input-15-352948ac74fd>", line 10
#     plt.bar(x_axis, y_axis)
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# # poverty rate by state in 2017

# %%
cleaned_poverty_df

poverty_2017 = cleaned_poverty_df.iloc[:, [0,1]]
poverty_2017

x_axis = (poverty_2017["State"])
y_axis = (poverty_2017["Percent (All People in Poverty)"])

plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 49 artists>
